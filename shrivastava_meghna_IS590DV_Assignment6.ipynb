# %%
import json

# %%
films = json.load(open("films.json"))

# %%
films
# Out:
# [{'fields': {'starships': [2, 3, 5, 9, 10, 11, 12, 13],
#    'edited': '2014-12-20T19:49:45.256Z',
#    'vehicles': [4, 6, 7, 8],
#    'planets': [1, 2, 3],
#    'producer': 'Gary Kurtz, Rick McCallum',
#    'title': 'A New Hope',
#    'created': '2014-12-10T14:23:31.880Z',
#    'episode_id': 4,
#    'director': 'George Lucas',
#    'release_date': '1977-05-25',
#    'opening_crawl': "It is a period of civil war.\r\nRebel spaceships, striking\r\nfrom a hidden base, have won\r\ntheir first victory against\r\nthe evil Galactic Empire.\r\n\r\nDuring the battle, Rebel\r\nspies managed to steal secret\r\nplans to the Empire's\r\nultimate weapon, the DEATH\r\nSTAR, an armored space\r\nstation with enough power\r\nto destroy an entire planet.\r\n\r\nPursued by the Empire's\r\nsinister agents, Princess\r\nLeia races home aboard her\r\nstarship, custodian of the\r\nstolen plans that can save her\r\npeople and restore\r\nfreedom to the galaxy....",
#    'characters': [1,
#     2,
#     3,
# ...

# %%
#char_input= json.load(open("shared/sp18-is590dv/data/star_wars/people.json"))
char_input = json.load(open("people.json"))

# %% [markdown]
# please use the file link as per your convinenence. I had difficulty in running the codes through online jupyter Hub server hence downloaded the file and ran on the local server.
# Have commented the original path above. Please run that url for your convinenence.

# %%
characters = {}
for character in char_input:
    characters[character['pk']] = character['fields']

# %%
for film in films:
    print("Film: ", film["fields"]["title"])
    for character in film["fields"]["characters"]:
        print(characters[character]["name"])
    print()
# Out:
# Film:  A New Hope
# Luke Skywalker
# C-3PO
# R2-D2
# Darth Vader
# Leia Organa
# Owen Lars
# Beru Whitesun lars
# R5-D4
# Biggs Darklighter
# Obi-Wan Kenobi
# Wilhuff Tarkin
# Chewbacca
# Han Solo
# Greedo
# Jabba Desilijic Tiure
# Wedge Antilles
# Jek Tono Porkins
# Raymus Antilles
#
# Film:  The Empire Strikes Back
# Luke Skywalker
# C-3PO
# R2-D2
# Darth Vader
# Leia Organa
# Obi-Wan Kenobi
# Chewbacca
# Han Solo
# Wedge Antilles
# Yoda
# Palpatine
# Boba Fett
# IG-88
# Bossk
# Lando Calrissian
# Lobot
#
# Film:  Return of the Jedi
# Luke Skywalker
# C-3PO
# R2-D2
# Darth Vader
# Leia Organa
# Obi-Wan Kenobi
# Chewbacca
# Han Solo
# Jabba Desilijic Tiure
# Wedge Antilles
# Yoda
# Palpatine
# Boba Fett
# Lando Calrissian
# Ackbar
# Mon Mothma
# Arvel Crynyd
# Wicket Systri Warrick
# Nien Nunb
# Bib Fortuna
#
# Film:  The Phantom Menace
# C-3PO
# R2-D2
# Obi-Wan Kenobi
# Anakin Skywalker
# Jabba Desilijic Tiure
# Yoda
# Palpatine
# Qui-Gon Jinn
# Nute Gunray
# Finis Valorum
# ...

# %%
import bqplot

# %%
chars = ["Luke Skywalker", "C-3PO", "R2-D2", "Darth Vader", "Leia Organa",
         "Owen Lars", "Beru Whitesun lars","R5-D4","Biggs Darklighter","Obi-Wan Kenobi",
         "Wilhuff Tarkin","Chewbacca","Han Solo","Greedo","Jabba Desilijic Tiure",
         "Wedge Antilles","Jek Tono Porkins","Raymus Antilles","Yoda","Palpatine",
         "Boba Fett","IG-88","Bossk","Lando Calrissian","Lobot", "Ackbar",
         "Mon Mothma","Arvel Crynyd","Wicket Systri Warrick","Nien Nunb",
        "Bib Fortuna"]
link_data = [{'source': 0, 'target': 1, 'value': 500}, 
             {'source': 0, 'target': 2, 'value': 500},
             {'source': 0, 'target': 3, 'value': 500},
             {'source': 0, 'target':  4, 'value': 500},
             {'source': 0, 'target':  5, 'value': 500},
             {'source': 0, 'target':  6, 'value': 500},
             {'source': 0, 'target':  7, 'value': 500},
             {'source': 0, 'target':  8, 'value': 500},
             {'source': 0, 'target':  9, 'value': 500},
             {'source': 0, 'target':  10, 'value': 500},
             {'source': 0, 'target':  11, 'value': 500},
             {'source': 0, 'target':  12, 'value': 500},
             {'source': 0, 'target':  13, 'value': 500},
             {'source': 0, 'target':  14, 'value': 500},
             {'source': 0, 'target':  15, 'value': 500},
             {'source': 0, 'target':  16, 'value': 500},
             {'source': 0, 'target':  17, 'value': 500},
             {'source': 0, 'target':  18, 'value': 500},
             {'source': 0, 'target':  19, 'value': 500},
             {'source': 0, 'target':  20, 'value': 500},
             {'source': 0, 'target':  21, 'value': 500},
             {'source': 0, 'target':  22, 'value': 500},
             {'source': 0, 'target':  23, 'value': 500},
             {'source': 0, 'target':  24, 'value': 500},
             {'source': 0, 'target':  25, 'value': 500},
             {'source': 0, 'target':  26, 'value': 500},
             {'source': 0, 'target':  27, 'value': 500},
             {'source': 0, 'target':  28, 'value': 500},
             {'source': 0, 'target':  29, 'value': 500},
             {'source': 0, 'target':  30, 'value': 500},
             {'source': 1, 'target':  2, 'value': 500},{'source': 1, 'target':  3, 'value': 500},{'source': 1, 'target':  4, 'value': 500},{'source': 1, 'target':  5, 'value': 500},{'source': 1, 'target':  6, 'value': 500}, {'source': 1, 'target':  7, 'value': 500},{'source': 1, 'target':  8, 'value': 500},{'source': 1, 'target':  9, 'value': 500},{'source': 1, 'target':  10, 'value': 500},
             {'source': 1, 'target':  11, 'value': 500},{'source': 1, 'target':  12, 'value': 500},{'source': 1, 'target':  13, 'value': 500},{'source': 1, 'target':  14, 'value': 500}, {'source': 1, 'target':  15, 'value': 500},
             {'source': 1, 'target':  16, 'value': 500}, {'source': 1, 'target':  17, 'value': 500}, {'source': 1, 'target':  18, 'value': 500}, {'source': 1, 'target':  19, 'value': 500},{'source': 1, 'target':  20, 'value': 500},
             {'source': 1, 'target':  21, 'value': 500}, {'source': 1, 'target':  22, 'value': 500}, {'source': 1, 'target':  23, 'value': 500},{'source': 1, 'target':  24, 'value': 500}, {'source': 1, 'target':  25, 'value': 500},
             {'source': 1, 'target':  26, 'value': 500}, {'source': 1, 'target':  27, 'value': 500}, {'source': 1, 'target':  28, 'value': 500}, {'source': 1, 'target':  29, 'value': 500}, {'source': 1, 'target':  30, 'value': 500},
             
             {'source': 2, 'target':  3, 'value': 10},{'source': 2, 'target':  4, 'value': 10},{'source': 2, 'target':  5, 'value': 10},{'source': 2, 'target':  6, 'value': 10}, {'source': 2, 'target':  7, 'value': 10},{'source': 2, 'target':  8, 'value': 10},{'source': 2, 'target':  9, 'value': 10},{'source': 2, 'target':  10, 'value': 10},
             {'source': 2, 'target':  11, 'value': 10},{'source': 2, 'target':  12, 'value': 10},{'source': 2, 'target':  13, 'value': 10},{'source': 2, 'target':  14, 'value': 10}, {'source': 2, 'target':  15, 'value': 10},
             {'source': 2, 'target':  16, 'value': 10}, {'source': 2, 'target':  17, 'value': 10}, {'source': 2, 'target':  18, 'value': 10}, {'source': 2, 'target':  19, 'value': 10},{'source': 2, 'target':  20, 'value': 10},
             {'source': 2, 'target':  21, 'value': 10}, {'source': 2, 'target':  22, 'value': 10}, {'source': 2, 'target':  23, 'value': 10},{'source': 2, 'target':  24, 'value': 10}, {'source': 2, 'target':  25, 'value': 10},
             {'source': 2, 'target':  26, 'value': 10}, {'source': 2, 'target':  27, 'value': 10}, {'source': 2, 'target':  28, 'value': 10}, {'source': 2, 'target':  29, 'value': 10}, {'source': 2, 'target':  30, 'value': 10},
            
             {'source': 3, 'target':  4, 'value': 10},{'source': 3, 'target':  5, 'value': 10},{'source': 3, 'target':  6, 'value': 10}, {'source': 3, 'target':  7, 'value': 10},{'source': 3, 'target':  8, 'value': 10},{'source': 3, 'target':  9, 'value': 10},{'source': 3, 'target':  10, 'value': 10},
             {'source': 3, 'target':  11, 'value': 10},{'source': 3, 'target':  12, 'value': 10},{'source': 3, 'target':  13, 'value': 10},{'source': 3, 'target':  14, 'value': 10}, {'source': 3, 'target':  15, 'value': 10},
             {'source': 3, 'target':  16, 'value': 10}, {'source': 3, 'target':  17, 'value': 10}, {'source': 3, 'target':  18, 'value': 10}, {'source': 3, 'target':  19, 'value': 10},{'source': 3, 'target':  20, 'value': 10},
             {'source': 3, 'target':  21, 'value': 10}, {'source': 3, 'target':  22, 'value': 10}, {'source': 3, 'target':  23, 'value': 10},{'source': 3, 'target':  24, 'value': 10}, {'source': 3, 'target':  25, 'value': 10},
             {'source': 3, 'target':  26, 'value': 10}, {'source': 3, 'target':  27, 'value': 10}, {'source': 3, 'target':  28, 'value': 10}, {'source': 3, 'target':  29, 'value': 10}, {'source': 3, 'target':  30, 'value': 10},
         
             {'source': 4, 'target':  5, 'value': 10},{'source': 4, 'target':  6, 'value': 10}, {'source': 4, 'target':  7, 'value': 10},{'source': 4, 'target':  8, 'value': 10},{'source': 4, 'target':  9, 'value': 10},{'source': 4, 'target':  10, 'value': 10},
             {'source': 4, 'target':  11, 'value': 10},{'source': 4, 'target':  12, 'value': 10},{'source': 4, 'target':  13, 'value': 10},{'source': 4, 'target':  14, 'value': 10}, {'source': 4, 'target':  15, 'value': 10},
             {'source': 4, 'target':  16, 'value': 10}, {'source': 4, 'target':  17, 'value': 10}, {'source': 4, 'target':  18, 'value': 10}, {'source': 4, 'target':  19, 'value': 10},{'source': 4, 'target':  20, 'value': 10},
             {'source': 4, 'target':  21, 'value': 10}, {'source': 4, 'target':  22, 'value': 10}, {'source': 4, 'target':  23, 'value': 10},{'source': 4, 'target':  24, 'value': 10}, {'source': 4, 'target':  25, 'value': 10},
             {'source': 4, 'target':  26, 'value': 10}, {'source': 4, 'target':  27, 'value': 10}, {'source': 4, 'target':  28, 'value': 10}, {'source': 4, 'target':  29, 'value': 10}, {'source': 4, 'target':  30, 'value': 10},
           
            {'source': 5, 'target':  6, 'value': 10}, {'source': 5, 'target':  7, 'value': 10},{'source': 5, 'target':  8, 'value': 10},{'source': 5, 'target':  9, 'value': 10},{'source': 5, 'target':  10, 'value': 10},
            {'source': 5, 'target':  11, 'value': 10},{'source': 5, 'target':  12, 'value': 10},{'source': 5, 'target':  13, 'value': 10},{'source': 5, 'target':  14, 'value': 10}, {'source': 5, 'target':  15, 'value': 10},
            {'source': 5, 'target':  16, 'value': 10},{'source': 5, 'target':  17, 'value': 10},
           
            {'source': 6, 'target':  7, 'value': 10},{'source': 6, 'target':  8, 'value': 10},{'source': 6, 'target':  9, 'value': 10},{'source': 6, 'target':  10, 'value': 10},
            {'source': 6, 'target':  11, 'value': 10},{'source': 6, 'target':  12, 'value': 10},{'source': 6, 'target':  13, 'value': 10},{'source': 6, 'target':  14, 'value': 10}, {'source': 6, 'target':  15, 'value': 10},
            {'source': 6, 'target':  16, 'value': 10},{'source': 6, 'target':  17, 'value': 10},
             
            {'source': 7, 'target':  8, 'value': 10},{'source': 7, 'target':  9, 'value': 10},{'source': 7, 'target':  10, 'value': 10},
            {'source': 7, 'target':  11, 'value': 10},{'source': 7, 'target':  12, 'value': 10},{'source': 7, 'target':  13, 'value': 10},{'source': 7, 'target':  14, 'value': 10}, {'source': 7, 'target':  15, 'value': 10},
            {'source': 7, 'target':  16, 'value': 10},{'source': 7, 'target':  17, 'value': 10},
             
            {'source': 8, 'target':  9, 'value': 10},{'source': 8, 'target':  10, 'value': 10},
            {'source': 8, 'target':  11, 'value': 10},{'source': 8, 'target':  12, 'value': 10},{'source': 8, 'target':  13, 'value': 10},{'source': 8, 'target':  14, 'value': 10}, {'source': 8, 'target':  15, 'value': 10},
            {'source': 8, 'target':  16, 'value': 10},{'source': 8, 'target':  17, 'value': 10},
            
            {'source': 9, 'target':  10, 'value': 10},{'source': 9, 'target':  11, 'value': 10},{'source': 9, 'target':  12, 'value': 10},{'source': 9, 'target':  13, 'value': 10},{'source': 9, 'target':  14, 'value': 10}, {'source': 9, 'target':  15, 'value': 10},
            {'source': 9, 'target':  16, 'value': 10},{'source': 9, 'target':  17, 'value': 10},{'source': 9, 'target':  18, 'value': 10},{'source': 9, 'target':  19, 'value': 10},{'source': 9, 'target':  20, 'value': 10},
            {'source': 9, 'target':  21, 'value': 10},{'source': 9, 'target':  22, 'value': 10},{'source': 9, 'target':  23, 'value': 10},{'source': 9, 'target':  24, 'value': 10}, {'source':9, 'target':  25, 'value': 10},
            {'source': 9, 'target':  26, 'value': 10},{'source': 9, 'target':  27, 'value': 10},{'source': 9, 'target':  28, 'value': 10},{'source': 9, 'target':  29, 'value': 10}, {'source':9, 'target':  30, 'value': 10},
            
            {'source': 10, 'target':  11, 'value': 10},{'source': 10, 'target':  12, 'value': 10},
            {'source': 10, 'target':  13, 'value': 10},{'source': 10, 'target':  14, 'value': 10},
            {'source': 10, 'target':  15, 'value': 10},{'source': 10, 'target':  16, 'value': 10},
            {'source': 10, 'target':  17, 'value': 10},
            
            {'source': 11, 'target':  12, 'value': 10},{'source': 11, 'target':  13, 'value': 10},{'source': 11, 'target':  14, 'value': 10},{'source': 11, 'target':  15, 'value': 10},
            {'source': 11, 'target':  16, 'value': 10},{'source': 11, 'target':  17, 'value': 10},{'source': 11, 'target':  18, 'value': 10},{'source': 11, 'target':  19, 'value': 10},{'source': 11, 'target':  20, 'value': 10},
            {'source': 11, 'target':  21, 'value': 10},{'source': 11, 'target':  22, 'value': 10},{'source': 11, 'target':  23, 'value': 10},{'source': 11, 'target':  24, 'value': 10}, {'source':11, 'target':  25, 'value': 10},
            {'source': 11, 'target':  26, 'value': 10},{'source': 11, 'target':  27, 'value': 10},{'source': 11, 'target':  28, 'value': 10},{'source': 11, 'target':  29, 'value': 10}, {'source':11, 'target':  30, 'value': 10},
            
            {'source': 12, 'target':  13, 'value': 10},{'source': 12, 'target':  14, 'value': 10},
            {'source': 12, 'target':  15, 'value': 10},
            {'source': 12, 'target':  16, 'value': 10},{'source': 12, 'target':  17, 'value': 10},
            {'source': 12, 'target':  18, 'value': 10},{'source': 12, 'target':  19, 'value': 10},
            {'source': 12, 'target':  20, 'value': 10},{'source': 12, 'target':  21, 'value': 10},
            {'source': 12, 'target':  22, 'value': 10},
            {'source': 12, 'target':  23, 'value': 10},{'source': 12, 'target':  24, 'value': 10}, 
            {'source':12, 'target':  25, 'value': 10},{'source': 12, 'target':  26, 'value': 10},
            {'source': 12, 'target':  27, 'value': 10},
            {'source': 12, 'target':  28, 'value': 10},{'source': 12, 'target':  29, 'value': 10},
            {'source':12, 'target':  30, 'value': 10},
             
            {'source': 13, 'target':  14, 'value': 100},
            {'source': 13, 'target':  15, 'value': 100},
            {'source': 13, 'target':  16, 'value': 100},
            {'source': 13, 'target':  17, 'value': 100},
             
            {'source': 14, 'target':  15, 'value': 100}, {'source': 14, 'target':  16, 'value': 100},
            {'source': 14, 'target':  17, 'value': 100},{'source':14, 'target':  25, 'value': 10},
            {'source': 14, 'target':  26, 'value': 10},
            {'source': 14, 'target':  27, 'value': 10},
            {'source': 14, 'target':  28, 'value': 10},{'source': 14, 'target':  29, 'value': 10},
            {'source':14, 'target':  30, 'value': 10},
             
            {'source': 15, 'target':  16, 'value': 100},{'source': 15, 'target':  17, 'value': 100},
            {'source': 15, 'target':  18, 'value': 100},{'source': 15, 'target':  19, 'value': 100},
            {'source': 15, 'target':  20, 'value': 100},{'source': 15, 'target':  21, 'value': 100},
            {'source': 15, 'target':  22, 'value': 100},{'source': 15, 'target':  23, 'value': 100},
            {'source': 15, 'target':  24, 'value': 100}, {'source':15, 'target':  25, 'value': 100},
            {'source': 15, 'target':  26, 'value': 100},{'source': 15, 'target':  27, 'value': 100},
            {'source': 15, 'target':  28, 'value': 100},{'source': 15, 'target':  29, 'value': 100},
            {'source':15, 'target':  30, 'value': 100},
            
            {'source': 16, 'target':  17, 'value': 100},
             
            {'source': 18, 'target':  19, 'value': 100},
            {'source': 18, 'target':  20, 'value': 100},{'source': 18, 'target':  21, 'value': 100},
            {'source': 18, 'target':  22, 'value': 100},{'source': 18, 'target':  23, 'value': 100},
            {'source': 18, 'target':  24, 'value': 100}, {'source':18, 'target':  25, 'value': 100},
            {'source': 18, 'target':  26, 'value': 100},{'source': 18, 'target':  27, 'value': 100},
            {'source': 18, 'target':  28, 'value': 100},{'source': 18, 'target':  29, 'value': 100},
            {'source':18, 'target':  30, 'value': 100},
             
            {'source': 19, 'target':  20, 'value': 100},{'source': 19, 'target':  21, 'value': 100},
            {'source': 19, 'target':  22, 'value': 100},{'source': 19, 'target':  23, 'value': 100},
            {'source': 19, 'target':  24, 'value': 100}, {'source':19, 'target':  25, 'value': 100},
            {'source': 19, 'target':  26, 'value': 100},{'source': 19, 'target':  27, 'value': 100},
            {'source': 19, 'target':  28, 'value': 100},{'source': 19, 'target':  29, 'value': 100},
            {'source':19, 'target':  30, 'value': 100},
             
            {'source': 20, 'target':  21, 'value': 100},
            {'source': 20, 'target':  22, 'value': 100},{'source': 20, 'target':  23, 'value': 100},
            {'source': 20, 'target':  24, 'value': 100}, {'source':20, 'target':  25, 'value': 100},
            {'source': 20, 'target':  26, 'value': 100},{'source': 20, 'target':  27, 'value': 100},
            {'source': 20, 'target':  28, 'value': 100},{'source': 20, 'target':  29, 'value': 100},
            {'source':20, 'target':  30, 'value': 100},
             
            {'source': 21, 'target':  22, 'value': 100},{'source': 21, 'target':  23, 'value': 100},
            {'source': 21, 'target':  24, 'value': 100},
             
            {'source': 22, 'target':  23, 'value': 100}, {'source': 22, 'target':  24, 'value': 100},
             
            {'source': 23, 'target':  24, 'value': 100}, {'source':23, 'target':  25, 'value': 100},
            {'source': 23, 'target':  26, 'value': 100},{'source': 23, 'target':  27, 'value': 100},
            {'source': 23, 'target':  28, 'value': 100},{'source': 23, 'target':  29, 'value': 100},
            {'source':23, 'target':  30, 'value': 100},
             
            {'source': 25, 'target':  26, 'value': 100},{'source': 25, 'target':  27, 'value': 100},
            {'source': 25, 'target':  28, 'value': 100},{'source': 25, 'target':  29, 'value': 100},
            {'source':25, 'target':  30, 'value': 100},
             
            {'source': 26, 'target':  27, 'value': 100},{'source': 26, 'target':  28, 'value': 100},
            {'source': 26, 'target':  29, 'value': 100}, {'source':26, 'target':  30, 'value': 100},
             
            {'source': 27, 'target':  28, 'value': 100},
            {'source': 27, 'target':  29, 'value': 100}, {'source':27, 'target':  30, 'value': 100},
            

            {'source': 28, 'target':  29, 'value': 100}, {'source':28, 'target':  30, 'value': 100},
             
            {'source':29, 'target':  30, 'value': 100}
            
            
        ]
tooltip = bqplot.Tooltip(fields=["label"])

graph = bqplot.Graph(node_data=chars, link_data=link_data, tooltip = tooltip,
                    colors = ["yellow"])


fig = bqplot.Figure(marks = [graph], size=(100,100))
display(fig)

def say_hello(obj, element):
    print(element)

graph.on_element_click(say_hello)
# Out:
# Figure(fig_margin={'top': 60, 'bottom': 60, 'left': 60, 'right': 60}, layout=Layout(min_width='125px'), marks=…
# {'event': 'element_click', 'data': {'label': 'Wedge Antilles', 'label_display': 'center', 'shape': 'circle', 'shape_attrs': {'r': 15}, 'value': None, 'index': 15, 'weight': 30, 'x': 324.74029082100196, 'y': 229.51219264379614, 'px': 324.74029082100196, 'py': 229.51219264379614, 'fixed': 0}}

# %% [markdown]
# I have constructed the network graph using for 3 films as mentioned below:
#
# Film:  A New Hope :
#
# Luke Skywalker
# C-3PO
# R2-D2
# Leia Organa
# Owen Lars
# Beru Whitesun lars
# R5-D4
# Biggs Darklighter
# Obi-Wan Kenobi
# Wilhuff Tarkin
# Chewbacca
# Han Solo
# Greedo
# Jabba Desilijic Tiure
# Wedge Antilles
# Jek Tono Porkins
# Raymus Antilles
#
# Film:  The Empire Strikes Back :
# Luke Skywalker
# C-3PO
# R2-D2
# Darth Vader
# Leia Organa
# Obi-Wan Kenobi
# Chewbacca
# Han Solo
# Wedge Antilles
# Yoda
# Palpatine
# Boba Fett
# IG-88
# Bossk
# Lando Calrissian
# Lobot
#
# Film:  Return of the Jedi :
# Luke Skywalker
# C-3PO
# R2-D2
# Darth Vader
# Leia Organa
# Obi-Wan Kenobi
# Chewbacca
# Han Solo
# Jabba Desilijic Tiure
# Wedge Antilles
# Yoda
# Palpatine
# Boba Fett
# Lando Calrissian
# Ackbar
# Mon Mothma
# Arvel Crynyd
# Wicket Systri Warrick
# Nien Nunb
# Bib Fortuna
